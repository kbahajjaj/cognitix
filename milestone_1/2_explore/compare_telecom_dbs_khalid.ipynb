# %%
import pandas as pd
from matplotlib import pyplot as plt
import gc

# %%
dft = pd.read_csv('t_telco_customer_churn.csv')
dfs = pd.read_csv('s_telecom_customer_churn.csv')
dfy = pd.read_csv('y_telecom_customer_churn.csv')
dfy2 = pd.read_csv('y2_telco_customer_churn.csv')

# %%
dft.head(1)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
#
#                  Lat Long   Latitude   Longitude Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783   Male  ...  Month-to-month
#
#   Paperless Billing Payment Method  Monthly Charges Total Charges Churn Label  \
# 0               Yes   Mailed check            53.85        108.15         Yes
#
#   Churn Value Churn Score  CLTV                  Churn Reason
# 0           1          86  3239  Competitor made better offer
#
# [1 rows x 33 columns]

# %%
dfs.head(1)
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...  Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...     Credit Card
#
#   Monthly Charge Total Charges  Total Refunds Total Extra Data Charges  \
# 0           65.6         593.3            0.0                        0
#
#   Total Long Distance Charges Total Revenue  Customer Status Churn Category  \
# 0                      381.51        974.81           Stayed            NaN
#
#   Churn Reason
# 0          NaN
#
# [1 rows x 38 columns]

# %%
dfy.head(1)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
#
# [1 rows x 21 columns]

# %%
dfy2.head(1)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
#
#                  Lat Long   Latitude   Longitude Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783   Male  ...  Month-to-month
#
#   Paperless Billing Payment Method  Monthly Charges Total Charges Churn Label  \
# 0               Yes   Mailed check            53.85        108.15         Yes
#
#   Churn Value Churn Score  CLTV                  Churn Reason
# 0           1          86  3239  Competitor made better offer
#
# [1 rows x 33 columns]

# %%
are_identical_t_y2 = dft.equals(dfy2)
are_identical_t_y2
# Out:
# True

# %%
are_identical_s_y = dfs.equals(dfy)
are_identical_s_y
# Out:
# False

# %%
del dfy2
gc.collect()
# Out:
# 0

# %%
dft = dft.sort_values('CustomerID').reset_index()
dfs = dfs.sort_values('Customer ID').reset_index()
dfy = dfy.sort_values('customerID').reset_index()

# %%
dft.head(5)
# Out:
#    index  CustomerID  Count        Country       State          City  \
# 0   3564  0002-ORFBO      1  United States  California  Frazier Park
# 1   4447  0003-MKNFE      1  United States  California      Glendale
# 2   1016  0004-TLHLJ      1  United States  California    Costa Mesa
# 3   1564  0011-IGKFF      1  United States  California      Martinez
# 4   1464  0013-EXCHZ      1  United States  California     Camarillo
#
#    Zip Code                Lat Long   Latitude   Longitude  ...  \
# 0     93225  34.827662, -118.999073  34.827662 -118.999073  ...
# 1     91206  34.162515, -118.203869  34.162515 -118.203869  ...
# 2     92627  33.645672, -117.922613  33.645672 -117.922613  ...
# 3     94553  38.014457, -122.115432  38.014457 -122.115432  ...
# 4     93010  34.227846, -119.079903  34.227846 -119.079903  ...
#
#          Contract Paperless Billing    Payment Method Monthly Charges  \
# 0        One year               Yes      Mailed check            65.6
# ...

# %%
dfs.head(5)
# Out:
#    index Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0      0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1      1  0003-MKNFE    Male   46      No                     0      Glendale
# 2      2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3      3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4      4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  ...   Payment Method  Monthly Charge  \
# 0     93225  34.827662 -118.999073  ...      Credit Card            65.6
# 1     91206  34.162515 -118.203869  ...      Credit Card            -4.0
# 2     92627  33.645672 -117.922613  ...  Bank Withdrawal            73.9
# 3     94553  38.014457 -122.115432  ...  Bank Withdrawal            98.0
# 4     93010  34.227846 -119.079903  ...      Credit Card            83.9
#
# ...

# %%
dfy.head(5)
# Out:
#    index  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0   2307  0002-ORFBO  Female              0     Yes        Yes       9
# 1   3488  0003-MKNFE    Male              0      No         No       9
# 2   3845  0004-TLHLJ    Male              0      No         No       4
# 3   5931  0011-IGKFF    Male              1     Yes         No      13
# 4   5569  0013-EXCHZ  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0          Yes            No             DSL  ...               No
# 1          Yes           Yes             DSL  ...               No
# 2          Yes            No     Fiber optic  ...              Yes
# 3          Yes            No     Fiber optic  ...              Yes
# 4          Yes            No     Fiber optic  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              7043 non-null   int64
#  1   CustomerID         7043 non-null   object
#  2   Count              7043 non-null   int64
#  3   Country            7043 non-null   object
#  4   State              7043 non-null   object
#  5   City               7043 non-null   object
#  6   Zip Code           7043 non-null   int64
#  7   Lat Long           7043 non-null   object
#  8   Latitude           7043 non-null   float64
#  9   Longitude          7043 non-null   float64
#  10  Gender             7043 non-null   object
#  11  Senior Citizen     7043 non-null   object
#  12  Partner            7043 non-null   object
#  13  Dependents         7043 non-null   object
#  14  Tenure Months      7043 non-null   int64
#  15  Phone Service      7043 non-null   object
# ...

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 39 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   index                              7043 non-null   int64
#  1   Customer ID                        7043 non-null   object
#  2   Gender                             7043 non-null   object
#  3   Age                                7043 non-null   int64
#  4   Married                            7043 non-null   object
#  5   Number of Dependents               7043 non-null   int64
#  6   City                               7043 non-null   object
#  7   Zip Code                           7043 non-null   int64
#  8   Latitude                           7043 non-null   float64
#  9   Longitude                          7043 non-null   float64
#  10  Number of Referrals                7043 non-null   int64
# ...

# %%
dfy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             7043 non-null   int64
#  1   customerID        7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %%
print(len(dft.columns), len(dfs.columns), len(dfy.columns))
dft_col = list(dft.columns)
#dft_col.sort()
dft_col.extend(['nothing' for _ in range(5)])
dfs_col = list(dfs.columns)
#dfs_col.sort()
dfy_col = list(dfy.columns)
#dfy_col.sort()
dfy_col.extend(['nothing' for _ in range(17)])
print(type(dft_col), type(dfs_col), type(dfy_col))
print(len(dft_col), len(dfs_col), len(dfy_col))
# Out:
# 34 39 22
# <class 'list'> <class 'list'> <class 'list'>
# 39 39 39

# %%
for i in range(len(dft_col)):
    print(dft_col[i],'    |    ',dfs_col[i], '    |    ',dfy_col[i])
# Out:
# index     |     index     |     index
# CustomerID     |     Customer ID     |     customerID
# Count     |     Gender     |     gender
# Country     |     Age     |     SeniorCitizen
# State     |     Married     |     Partner
# City     |     Number of Dependents     |     Dependents
# Zip Code     |     City     |     tenure
# Lat Long     |     Zip Code     |     PhoneService
# Latitude     |     Latitude     |     MultipleLines
# Longitude     |     Longitude     |     InternetService
# Gender     |     Number of Referrals     |     OnlineSecurity
# Senior Citizen     |     Tenure in Months     |     OnlineBackup
# Partner     |     Offer     |     DeviceProtection
# Dependents     |     Phone Service     |     TechSupport
# Tenure Months     |     Avg Monthly Long Distance Charges     |     StreamingTV
# Phone Service     |     Multiple Lines     |     StreamingMovies
# Multiple Lines     |     Internet Service     |     Contract
# ...

# %%
cols_df = pd.DataFrame(data={'toqa':dft_col, 'salma':dfs_col, 'yousef':dfy_col})
cols_df.head(15)
# Out:
#               toqa                              salma            yousef
# 0            Index                              Index             Index
# 1       Customerid                        Customer Id        Customerid
# 2            Count                             Gender            Gender
# 3          Country                                Age     Seniorcitizen
# 4            State                            Married           Partner
# 5             City               Number Of Dependents        Dependents
# 6         Zip Code                               City            Tenure
# 7         Lat Long                           Zip Code      Phoneservice
# 8         Latitude                           Latitude     Multiplelines
# 9        Longitude                          Longitude   Internetservice
# 10          Gender                Number Of Referrals    Onlinesecurity
# 11  Senior Citizen                   Tenure In Months      Onlinebackup
# ...

# %%
print(set(dft['CustomerID']))
# Out:
# {'7526-BEZQB', '8871-JLMHM', '2300-RQGOI', '7167-PCEYD', '4114-QMKVN', '8190-ZTQFB', '0256-LTHVJ', '8944-AILEF', '8276-MQBYC', '9257-AZMTZ', '7301-ABVAD', '4566-QVRRW', '0384-RVBPI', '5828-DWPIL', '9391-LMANN', '9585-KKMFD', '8835-VSDSE', '1057-FOGLZ', '0661-WCQNQ', '3744-ZBHON', '9351-HXDMR', '4320-QMLLA', '7729-XBTWX', '2569-WGERO', '0687-ZVTHB', '8652-YHIYU', '6366-ZGQGL', '0235-KGSLC', '3889-VWBID', '2235-ZGKPT', '5726-CVNYA', '4312-KFRXN', '5172-RKOCB', '7401-JIXNM', '6821-JPCDC', '0224-HJAPT', '4670-TABXH', '9531-NSBMR', '7853-OETYL', '0218-QNVAS', '1907-UBQFC', '8510-BBWMU', '2924-KHUVI', '1184-PJVDB', '6993-YCOBK', '4640-UHDOS', '8402-EIVQS', '3754-DXMRT', '7716-YTYHG', '0461-CVKMU', '7813-ZGGAW', '3266-FTKHB', '9236-NDUCW', '6988-CJEYV', '4238-HFHSN', '1661-CZBAU', '1320-REHCS', '6292-TOSSS', '7950-XWOVN', '5207-PLSTK', '6581-NQCBA', '5846-NEQVZ', '9348-YVOMK', '0068-FIGTF', '0559-CKHUS', '1060-ENTOF', '1114-CENIM', '1257-SXUXQ', '5445-GLVOT', '6288-LBEAR', '3258-SANFR', '42
# ...

# %%
t_of_s = set(dft['CustomerID']).issubset(dfs['Customer ID'])
y_of_s = set(dfy['customerID']).issubset(dfs['Customer ID'])
print(t_of_s)
print(y_of_s)
# Out:
# True
# True

# %%
print(len(list(dft['CustomerID'])), len(set(dft['CustomerID'])))
# Out:
# 7043 7043

# %%
all_columns = list(dft.columns)
all_columns.extend(list(dfs.columns))
all_columns.extend(list(dfy.columns))
print(f"length of all columns list = {len(all_columns)}")
# print(all_columns)
all_columns = set(all_columns)
print(f"length of all columns set (removed duplicates) = {len(all_columns)}",'\n\n\n')
# print(all_columns)
# t_s_titles = [title for title in dft.columns if title in dfs.columns]
# t_y_titles = [title for title in dft.columns if title in dfy.columns]
# s_y_titles = [title for title in dfs.columns if title in dfy.columns]

t_s_y_titles = []
t_s_titles = []
t_y_titles = []
s_y_titles = []
uncommon_titles = []
for title in all_columns:
    # if (title in dft.columns) and (title in dfs.columns) and (title in dfy.columns):
    #     t_s_y_titles.append(title)
    if (title in dfs.columns) and (title in dfy.columns):
        s_y_titles.append(title)    
    if (title in dft.columns) and (title in dfs.columns):
        t_s_titles.append(title)
    if (title in dft.columns) and (title in dfy.columns):
        t_y_titles.append(title)
    uncommon_titles = all_columns.difference(set(t_s_titles)).difference(set(t_y_titles)).difference(set(s_y_titles))
#print(f"--> {len(t_s_y_titles)} common_titles between Toqa & Samla & Yousef DBs:\n\n", t_s_y_titles, '\n')
print(f"--> {len(t_s_titles)} common_titles between Toqa & Samla DBs:\n\n", t_s_titles, '\n')
print(f"--> {len(t_y_titles)} common_titles between Toqa & Yousef DBs:\n\n", t_y_titles, '\n')
print(f"--> {len(s_y_titles)} common_titles between Samla & Yousef DBs:\n\n", s_y_titles, '\n')
print(f"--> {len(uncommon_titles)} uncommon_titles:\n\n", uncommon_titles)
# Out:
# length of all columns list = 95
# length of all columns set (removed duplicates) = 73
#
#
#
# --> 18 common_titles between Toqa & Samla DBs:
#
#  ['Multiple Lines', 'Contract', 'Streaming Movies', 'Churn Reason', 'Total Charges', 'Internet Service', 'index', 'City', 'Streaming TV', 'Longitude', 'Zip Code', 'Phone Service', 'Online Backup', 'Online Security', 'Paperless Billing', 'Payment Method', 'Gender', 'Latitude']
#
# --> 4 common_titles between Toqa & Yousef DBs:
#
#  ['Contract', 'Dependents', 'index', 'Partner']
#
# --> 2 common_titles between Samla & Yousef DBs:
#
#  ['Contract', 'index']
#
# --> 53 uncommon_titles:
#
# ...

# %%
print(len(dft.columns), len(dfs.columns), len(dfy.columns))
dft_col = list(dft.columns)
dft_col.extend(['nothing' for _ in range(5)])
dfs_col = list(dfs.columns)
dfy_col = list(dfy.columns)
dfy_col.extend(['nothing' for _ in range(17)])
# Out:
# 34 39 22

# %%
cols_df = pd.DataFrame(data={'toqa':dft_col, 'salma':dfs_col, 'yousef':dfy_col})
cols_df
# Out:
#                  toqa                              salma            yousef
# 0               index                              index             index
# 1          CustomerID                        Customer ID        customerID
# 2               Count                             Gender            gender
# 3             Country                                Age     SeniorCitizen
# 4               State                            Married           Partner
# 5                City               Number of Dependents        Dependents
# 6            Zip Code                               City            tenure
# 7            Lat Long                           Zip Code      PhoneService
# 8            Latitude                           Latitude     MultipleLines
# 9           Longitude                          Longitude   InternetService
# 10             Gender                Number of Referrals    OnlineSecurity
# ...

# %%
# modify columns names:
dft.columns = dft.columns.str.title()
dfs.columns = dfs.columns.str.title()
dfy.columns = dfy.columns.str.title()

# %%
print(len(dft.columns), len(dfs.columns), len(dfy.columns))
dft_col = list(dft.columns)
dft_col.extend(['nothing' for _ in range(5)])
dfs_col = list(dfs.columns)
dfy_col = list(dfy.columns)
dfy_col.extend(['nothing' for _ in range(17)])

cols_df = pd.DataFrame(data={'toqa':dft_col, 'salma':dfs_col, 'yousef':dfy_col})
cols_df
# Out:
# 34 39 22
#                  toqa                              salma            yousef
# 0               Index                              Index             Index
# 1          Customerid                        Customer Id        Customerid
# 2               Count                             Gender            Gender
# 3             Country                                Age     Seniorcitizen
# 4               State                            Married           Partner
# 5                City               Number Of Dependents        Dependents
# 6            Zip Code                               City            Tenure
# 7            Lat Long                           Zip Code      Phoneservice
# 8            Latitude                           Latitude     Multiplelines
# 9           Longitude                          Longitude   Internetservice
# 10             Gender                Number Of Referrals    Onlinesecurity
# ...

# %%
all_columns = list(dft.columns)
all_columns.extend(list(dfs.columns))
all_columns.extend(list(dfy.columns))
print(f"length of all columns list = {len(all_columns)}")
# print(all_columns)
all_columns = set(all_columns)
print(f"length of all columns set (removed duplicates) = {len(all_columns)}",'\n\n\n')
# print(all_columns)
# t_s_titles = [title for title in dft.columns if title in dfs.columns]
# t_y_titles = [title for title in dft.columns if title in dfy.columns]
# s_y_titles = [title for title in dfs.columns if title in dfy.columns]

t_s_y_titles = []
t_s_titles = []
t_y_titles = []
s_y_titles = []
uncommon_titles = []
for title in all_columns:
    # if (title in dft.columns) and (title in dfs.columns) and (title in dfy.columns):
    #     t_s_y_titles.append(title)
    if (title in dfs.columns) and (title in dfy.columns):
        s_y_titles.append(title)    
    if (title in dft.columns) and (title in dfs.columns):
        t_s_titles.append(title)
    if (title in dft.columns) and (title in dfy.columns):
        t_y_titles.append(title)
    uncommon_titles = all_columns.difference(set(t_s_titles)).difference(set(t_y_titles)).difference(set(s_y_titles))
#print(f"--> {len(t_s_y_titles)} common_titles between Toqa & Samla & Yousef DBs:\n\n", t_s_y_titles, '\n')
print(f"--> {len(t_s_titles)} common_titles between Toqa & Samla DBs:\n\n", t_s_titles, '\n')
print(f"--> {len(t_y_titles)} common_titles between Toqa & Yousef DBs:\n\n", t_y_titles, '\n')
print(f"--> {len(s_y_titles)} common_titles between Samla & Yousef DBs:\n\n", s_y_titles, '\n')
print(f"--> {len(uncommon_titles)} uncommon_titles:\n\n", uncommon_titles)

print(len(dft.columns), len(dfs.columns), len(dfy.columns))
dft_col = list(dft.columns)
dft_col.extend(['nothing' for _ in range(5)])
dfs_col = list(dfs.columns)
dfy_col = list(dfy.columns)
dfy_col.extend(['nothing' for _ in range(17)])

cols_df = pd.DataFrame(data={'toqa':dft_col, 'salma':dfs_col, 'yousef':dfy_col})
cols_df

check_similar_columns = list(uncommon_titles)
check_similar_columns.sort()
print(check_similar_columns)
# Out:
# length of all columns list = 95
# length of all columns set (removed duplicates) = 71
#
#
#
# --> 18 common_titles between Toqa & Samla DBs:
#
#  ['Multiple Lines', 'Contract', 'Streaming Movies', 'Churn Reason', 'Total Charges', 'Internet Service', 'City', 'Index', 'Longitude', 'Zip Code', 'Phone Service', 'Online Backup', 'Online Security', 'Paperless Billing', 'Payment Method', 'Gender', 'Streaming Tv', 'Latitude']
#
# --> 6 common_titles between Toqa & Yousef DBs:
#
#  ['Contract', 'Dependents', 'Partner', 'Index', 'Customerid', 'Gender']
#
# --> 3 common_titles between Samla & Yousef DBs:
#
#  ['Contract', 'Index', 'Gender']
#
# --> 50 uncommon_titles:
#
# ...

# %%
for title in t_s_titles:
    print(title)
    if dft[title].equals(dfs[title]):
        print('#####identical#########')
# Out:
# Multiple Lines
# Contract
# Streaming Movies
# Churn Reason
# Total Charges
# Internet Service
# City
# Index
# Longitude
# Zip Code
# Phone Service
# #####identical#########
# Online Backup
# Online Security
# Paperless Billing
# #####identical#########
# Payment Method
# Gender
# #####identical#########
# Streaming Tv
# Latitude

# %%
dft['Customerid'].nunique()
# Out:
# 7043

# %%
print(type(dft['Phone Service']))
print(len(dft['Phone Service']))
print(len(dfs['Phone Service']))
# Out:
# <class 'pandas.core.series.Series'>
# 7043
# 7043

# %%
dfs['Phone Service'].head(20)
# Out:
# 0     Yes
# 1     Yes
# 2     Yes
# 3     Yes
# 4     Yes
# 5     Yes
# 6     Yes
# 7     Yes
# 8     Yes
# 9     Yes
# 10     No
# 11    Yes
# 12    Yes
# 13    Yes
# 14     No
# 15    Yes
# 16     No
# 17    Yes
# 18    Yes
# 19     No
# Name: Phone Service, dtype: object

# %%
dft['Phone Service'].head(20)
# Out:
# 0     Yes
# 1     Yes
# 2     Yes
# 3     Yes
# 4     Yes
# 5     Yes
# 6     Yes
# 7     Yes
# 8     Yes
# 9     Yes
# 10     No
# 11    Yes
# 12    Yes
# 13    Yes
# 14     No
# 15    Yes
# 16     No
# 17    Yes
# 18    Yes
# 19     No
# Name: Phone Service, dtype: object

# %%
replacement_map = {'Yes': True, 'No': False}
x = dft['Phone Service'].map(replacement_map).sum()
y = dft['Phone Service'].map(replacement_map).sum()
print(x, y)
# Out:
# 6361 6361

# %%
		
dft = dft.rename(columns={'Customerid':'Customer ID'})
dfs = dfs.rename(columns={'Customer Id':'Customer ID'})
dfy = dfy.rename(columns={'Customerid':'Customer ID'})
df_t_s = pd.merge(dft, dfs, on='Customer ID')
df_t_s_y = pd.merge(df_t_s, dfy, on='Customer ID')

# %%
df_t_s_y.head(10)
# Out:
#    Index_x Customer ID  Count        Country       State        City_x  \
# 0     3564  0002-ORFBO      1  United States  California  Frazier Park
# 1     4447  0003-MKNFE      1  United States  California      Glendale
# 2     1016  0004-TLHLJ      1  United States  California    Costa Mesa
# 3     1564  0011-IGKFF      1  United States  California      Martinez
# 4     1464  0013-EXCHZ      1  United States  California     Camarillo
# 5     2764  0013-MHZWF      1  United States  California      Midpines
# 6     3624  0013-SMEOE      1  United States  California        Lompoc
# 7     3815  0014-BMAQU      1  United States  California          Napa
# 8     3547  0015-UOCOJ      1  United States  California   Simi Valley
# 9     5349  0016-QLJIS      1  United States  California      Sheridan
#
#    Zip Code_x                Lat Long  Latitude_x  Longitude_x  ...  \
# 0       93225  34.827662, -118.999073   34.827662  -118.999073  ...
# ...

# %%
df_t_s_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 93 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Index_x                            7043 non-null   int64
#  1   Customer ID                        7043 non-null   object
#  2   Count                              7043 non-null   int64
#  3   Country                            7043 non-null   object
#  4   State                              7043 non-null   object
#  5   City_x                             7043 non-null   object
#  6   Zip Code_x                         7043 non-null   int64
#  7   Lat Long                           7043 non-null   object
#  8   Latitude_x                         7043 non-null   float64
#  9   Longitude_x                        7043 non-null   float64
#  10  Gender_x                           7043 non-null   object
# ...
