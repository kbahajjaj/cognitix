# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
dft = pd.read_csv('t_telco_customer_churn.csv')
dfs = pd.read_csv('s_telecom_customer_churn.csv')
dfy = pd.read_csv('y_telecom_customer_churn.csv')
dfy2 = pd.read_csv('y2_telco_customer_churn.csv')

# %%
dft.head(1)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
#
#                  Lat Long   Latitude   Longitude Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783   Male  ...  Month-to-month
#
#   Paperless Billing Payment Method  Monthly Charges Total Charges Churn Label  \
# 0               Yes   Mailed check            53.85        108.15         Yes
#
#   Churn Value Churn Score  CLTV                  Churn Reason
# 0           1          86  3239  Competitor made better offer
#
# [1 rows x 33 columns]

# %%
dfs.head(1)
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...  Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...     Credit Card
#
#   Monthly Charge Total Charges  Total Refunds Total Extra Data Charges  \
# 0           65.6         593.3            0.0                        0
#
#   Total Long Distance Charges Total Revenue  Customer Status Churn Category  \
# 0                      381.51        974.81           Stayed            NaN
#
#   Churn Reason
# 0          NaN
#
# [1 rows x 38 columns]

# %%
dfy.head(1)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
#
# [1 rows x 21 columns]

# %%
dfy2.head(1)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
#
#                  Lat Long   Latitude   Longitude Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783   Male  ...  Month-to-month
#
#   Paperless Billing Payment Method  Monthly Charges Total Charges Churn Label  \
# 0               Yes   Mailed check            53.85        108.15         Yes
#
#   Churn Value Churn Score  CLTV                  Churn Reason
# 0           1          86  3239  Competitor made better offer
#
# [1 rows x 33 columns]

# %%
are_identical_t_y2 = dft.equals(dfy2)
are_identical_t_y2
# Out:
# True

# %%
are_identical_s_y = dfs.equals(dfy)
are_identical_s_y
# Out:
# False

# %%
del dfy2

# %%
dft = dft.sort_values('CustomerID')
dfs = dfs.sort_values('Customer ID')
dfy = dfy.sort_values('customerID')

# %%
dft.head(5)
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 3564  0002-ORFBO      1  United States  California  Frazier Park     93225
# 4447  0003-MKNFE      1  United States  California      Glendale     91206
# 1016  0004-TLHLJ      1  United States  California    Costa Mesa     92627
# 1564  0011-IGKFF      1  United States  California      Martinez     94553
# 1464  0013-EXCHZ      1  United States  California     Camarillo     93010
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 3564  34.827662, -118.999073  34.827662 -118.999073  Female  ...
# 4447  34.162515, -118.203869  34.162515 -118.203869    Male  ...
# 1016  33.645672, -117.922613  33.645672 -117.922613    Male  ...
# 1564  38.014457, -122.115432  38.014457 -122.115432    Male  ...
# 1464  34.227846, -119.079903  34.227846 -119.079903  Female  ...
#
#             Contract Paperless Billing    Payment Method  Monthly Charges  \
# ...

# %%
dfs.head(5)
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
# ...

# %%
dfy.head(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2307  0002-ORFBO  Female              0     Yes        Yes       9
# 3488  0003-MKNFE    Male              0      No         No       9
# 3845  0004-TLHLJ    Male              0      No         No       4
# 5931  0011-IGKFF    Male              1     Yes         No      13
# 5569  0013-EXCHZ  Female              1     Yes         No       3
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2307          Yes            No             DSL             No  ...
# 3488          Yes           Yes             DSL             No  ...
# 3845          Yes            No     Fiber optic             No  ...
# 5931          Yes            No     Fiber optic             No  ...
# 5569          Yes            No     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 3564 to 3073
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   City                               7043 non-null   object
#  6   Zip Code                           7043 non-null   int64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Number of Referrals                7043 non-null   int64
#  10  Tenure in Months                   7043 non-null   int64
# ...

# %%
dfy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 2307 to 1634
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
print(len(dft.columns), len(dfs.columns), len(dfy.columns))
dft_col = list(dft.columns)
#dft_col.sort()
dft_col.extend(['nothing' for _ in range(5)])
dfs_col = list(dfs.columns)
#dfs_col.sort()
dfy_col = list(dfy.columns)
#dfy_col.sort()
dfy_col.extend(['nothing' for _ in range(17)])
print(type(dft_col), type(dfs_col), type(dfy_col))
print(len(dft_col), len(dfs_col), len(dfy_col))
# Out:
# 33 38 21
# <class 'list'> <class 'list'> <class 'list'>
# 38 38 38

# %%
for i in range(len(dft_col)):
    print(dft_col[i],'    |    ',dfs_col[i], '    |    ',dfy_col[i])
# Out:
# CustomerID     |     Customer ID     |     customerID
# Count     |     Gender     |     gender
# Country     |     Age     |     SeniorCitizen
# State     |     Married     |     Partner
# City     |     Number of Dependents     |     Dependents
# Zip Code     |     City     |     tenure
# Lat Long     |     Zip Code     |     PhoneService
# Latitude     |     Latitude     |     MultipleLines
# Longitude     |     Longitude     |     InternetService
# Gender     |     Number of Referrals     |     OnlineSecurity
# Senior Citizen     |     Tenure in Months     |     OnlineBackup
# Partner     |     Offer     |     DeviceProtection
# Dependents     |     Phone Service     |     TechSupport
# Tenure Months     |     Avg Monthly Long Distance Charges     |     StreamingTV
# Phone Service     |     Multiple Lines     |     StreamingMovies
# Multiple Lines     |     Internet Service     |     Contract
# Internet Service     |     Internet Type     |     PaperlessBilling
# ...

# %%
cols_df = pd.DataFrame(data={'toqa':dft_col, 'salma':dfs_col, 'yousef':dfy_col})
cols_df.head()
# Out:
#          toqa                 salma         yousef
# 0  CustomerID           Customer ID     customerID
# 1       Count                Gender         gender
# 2     Country                   Age  SeniorCitizen
# 3       State               Married        Partner
# 4        City  Number of Dependents     Dependents

# %%
print(set(dft['CustomerID']))
# Out:
# {'5215-LNLDJ', '0816-TSPHQ', '8185-UPYBR', '4012-YCFAI', '3567-PQTSO', '6723-CEGQI', '7279-BUYWN', '5044-LRQAQ', '3571-RFHAR', '8992-CEUEN', '1029-QFBEN', '2983-ZANRP', '6152-ONASV', '5456-ITGIC', '9074-KGVOX', '2371-JQHZZ', '4936-YPJNK', '5384-ZTTWP', '9853-JFZDU', '1699-HPSBG', '9091-WTUUY', '1926-QUZNN', '2878-RMWXY', '5944-UGLLK', '6022-UGGSO', '3249-VHRIP', '4425-OWHWB', '6693-FRIRW', '7672-VFMXZ', '4826-XTSOH', '8766-PAFNE', '7776-QGYJC', '2408-WITXK', '3798-EPWRR', '9845-QOMAD', '7908-QCBCA', '5480-TBGPH', '3911-RSNHI', '0581-BXBUB', '1791-PQHBB', '0058-EVZWM', '3717-OFRTN', '6695-FRVEC', '0487-VVUVK', '7245-JMTTQ', '3717-FDJFU', '2845-KDHVX', '7558-IMLMT', '0640-YJTPY', '4770-UEZOX', '4065-JJAVA', '2373-NTKOD', '3316-UWXUY', '4137-BTIKL', '2070-FNEXE', '3973-SKMLN', '0691-NIKRI', '4712-AUQZO', '8910-ICHIU', '0848-ZGQIJ', '2017-CCBLH', '2252-JHJGE', '2656-TABEH', '4282-YMKNA', '8807-OPMBM', '8718-PTMEZ', '9250-WYPLL', '8919-FYFQZ', '6198-ZFIOJ', '9087-EYCPR', '0869-PAPRP', '93
# ...

# %%
t_of_s = set(dft['CustomerID']).issubset(dfs['Customer ID'])
y_of_s = set(dfy['customerID']).issubset(dfs['Customer ID'])
print(t_of_s)
print(y_of_s)
# Out:
# True
# True

# %%
"""dft.columns = dft.columns.str.title()
dfs.columns = dfs.columns.str.title()
dft.columns = dfy.columns.str.title()"""
# Out:
# 'dft.columns = dft.columns.str.title()\ndfs.columns = dfs.columns.str.title()\ndft.columns = dfy.columns.str.title()'

# %%
print(len(list(dft['CustomerID'])), len(set(dft['CustomerID'])))
# Out:
# 7043 7043
